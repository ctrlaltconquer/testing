# %%
import pandas as pd 
import numpy as np 
import random

# Define the number of rows in the dataset
num_rows = 20000


# Define possible values for each column


skill_level = [random.choice(['Beginner', 'Intermediate', 'Advanced']) for _ in range(num_rows)]
learning_style = [random.choice(['hands-on coding', 'visual programming', 'Theoritical approach']) for _ in range(num_rows)]
project_types = [random.choice(['Web Development', 'Mobile App Development','Android App Development','Data Science', 'Artificial Intelligence', 'Game Development', 'Embedded Systems', 'Desktop Application Development', 'DevOps', 'Blockchain Development', 'Cybersecurity', 'Internet of Things', 'Argumented Reality and Virtual Reality', 'Cloud Computing', 'E-commerce', 'Healthcare IT', 'System Programming', 'Signal Processing', 'Statistics', 'Frontend Development', 'Full-stack Development','API Development','Data Analysis','Scripting', 'Automation', 'System Administration']) for _ in range(num_rows)]
cross_platform_compatibility = [random.choice(['Yes', 'No']) for _ in range(num_rows)] #Are you interested in developing applications that run on multiple platforms (Windows, macOS, Linux, etc.)?
industry_trends = [random.choice(['Much', 'Not at all', 'Rare']) for _ in range(num_rows)] #How interested are you in staying up-to-date with current industry trends and adopting emerging technologies in your projects?
ecosystems_and_tools = [random.choice(['Yes', 'No', 'Not sure']) for _ in range(num_rows)] #Do you prefer working with languages that have a rich ecosystem, offering a variety of tools, frameworks, and libraries?
scalibility = [random.choice(['Small Scale', 'Large Scale', 'Mix of Both']) for _ in range(num_rows)] #Scalability:Do you foresee yourself working on small-scale projects, large-scale enterprise applications, or a mix of both?
data_handling = [random.choice(['Yes', 'No', 'Not sure']) for _ in range(num_rows)] #Are you interested in working with large datasets and performing data analysis or machine learning tasks?
documentation_importance = [random.choice(['Yes', 'No', 'Not sure']) for _ in range(num_rows)] #How important is well-documented language and library documentation in your decision-making process?


language = ["" for _ in range(num_rows)]

for i in range(num_rows):
    if skill_level[i] in ['Intermediate', 'Advanced'] and \
       learning_style[i] == 'hands-on coding' and \
       project_types[i] in ['Web Development', 'Mobile App Development', 'Data Science', 'Artificial Intelligence', 'Game Development', 'Embedded Systems', 'Desktop Application Development', 'DevOps', 'Blockchain Development', 'Cybersecurity', 'Internet of Things', 'Argumented Reality and Virtual Reality', 'Cloud Computing', 'E-commerce', 'Healthcare IT'] and \
       cross_platform_compatibility[i] == 'Yes' and \
       industry_trends[i] in ['Much'] and \
       ecosystems_and_tools[i] in ['Yes'] and \
       scalibility[i] in ['Small Scale', 'Large Scale', 'Mix of Both'] and \
       data_handling[i] in ['Yes', 'Not sure'] and \
       documentation_importance[i] in ['Yes']:
        language[i]="Java"
    
    elif skill_level[i] in ['Intermediate', 'Beginner'] and \
       learning_style[i] in ['hands-on coding', 'visual programming'] and \
       project_types[i] in ['Web Development', 'Mobile App Development', 'Data Science', 'Artificial Intelligence', 'Game Development', 'Embedded Systems', 'DevOps', 'Blockchain Development', 'Internet of Things', 'Argumented Reality and Virtual Reality', 'Cloud Computing', 'E-commerce'] and \
       cross_platform_compatibility[i] in ['Yes', 'No'] and \
       industry_trends[i] in ['Much', 'Rare'] and \
       ecosystems_and_tools[i] in ['Yes', 'Not sure'] and \
       scalibility[i] in ['Small Scale', 'Large Scale', 'Mix of Both'] and \
       data_handling[i] in ['Yes', 'No'] and \
       documentation_importance[i] in ['Yes', 'Not sure']:
        language[i]="JavaScript"
        
    elif skill_level[i] in ['Intermediate', 'Beginner'] and \
       learning_style[i] in ['hands-on coding', 'Theoritical approach'] and \
       project_types[i] in ['Desktop Application Development', 'Game Development', 'Embedded Systems', 'System Programming'] and \
       cross_platform_compatibility[i] in ['Yes', 'No'] and \
       industry_trends[i] in ['Much', 'Not at all'] and \
       ecosystems_and_tools[i] in ['Yes', 'No'] and \
       scalibility[i] in ['Small Scale', 'Large Scale'] and \
       data_handling[i] in ['Yes', 'No'] and \
       documentation_importance[i] in ['Yes', 'No']:
        language[i] = "C++"

    elif skill_level[i] in ['Beginner'] and \
       learning_style[i] in ['hands-on coding', 'Theoritical approach'] and \
       documentation_importance[i] in ['Yes', 'No']:
        language[i] = "C"
    
    elif skill_level[i] in ['Intermediate', 'Advanced', 'Beginner'] and \
       learning_style[i] in ['hands-on coding'] and \
       project_types[i] in ['Web Development', 'Mobile App Development', 'Data Science', 'Artificial Intelligence', 'Game Development', 'Embedded Systems', 'DevOps', 'Blockchain Development', 'Cybersecurity', 'Internet of Things', 'Cloud Computing'] and \
       cross_platform_compatibility[i] in ['Yes', 'No'] and \
       industry_trends[i] in ['Much', 'Rare'] and \
       ecosystems_and_tools[i] in ['Yes'] and \
       scalibility[i] in ['Small Scale', 'Large Scale', 'Mix of Both'] and \
       data_handling[i] in ['Yes', 'Not sure'] and \
       documentation_importance[i] in ['Yes', 'Not sure']:
        language[i] = "Python"
        
    elif skill_level[i] in ['Intermediate', 'Beginner'] and \
       learning_style[i] in ['hands-on coding', 'visual programming'] and \
       project_types[i] in ['Web Development', 'E-commerce'] and \
       data_handling[i] in ['Yes', 'No'] and \
       documentation_importance[i] in ['Yes', 'Not sure']:
        language[i] = "PHP"

    elif skill_level[i] in ['Intermediate', 'Advanced'] and \
       learning_style[i] in ['hands-on coding', 'visual programming'] and \
       project_types[i] in ['Web Development', 'Desktop Application Development', 'Game Development', 'DevOps', 'Blockchain Development'] and \
       cross_platform_compatibility[i] == 'No' and \
       data_handling[i] in ['Yes', 'No'] and \
       documentation_importance[i] in ['Yes', 'Not sure']:
        language[i] = "C#"
    
    elif skill_level[i] in ['Intermediate', 'Advanced'] and \
       project_types[i] in ['Scripting', 'Automation', 'System Administration']:
        language[i] = "PowerShell"
        
    elif skill_level[i] in ['Intermediate', 'Advanced'] and \
       learning_style[i] in ['hands-on coding', 'Theoritical approach'] and \
       project_types[i] in ['Data Science', 'Statistics', 'Machine Learning']:
        language[i] = "R"
    

    elif skill_level[i] in ['Intermediate', 'Advanced'] and \
       learning_style[i] in ['hands-on coding'] and \
       project_types[i] in ['Scripting', 'Web Development'] and \
       cross_platform_compatibility[i] in ['Yes', 'No']:
        language[i] = "Perl"
        
    elif skill_level[i] in ['Intermediate', 'Advanced'] and \
       learning_style[i] in ['hands-on coding'] and \
       project_types[i] in ['Web Development', 'Scripting'] and \
       cross_platform_compatibility[i] in ['Yes', 'No'] and \
       scalibility[i] in ['Small Scale', 'Large Scale', 'Mix of Both']:
        language[i] = "Ruby"
    
    elif skill_level[i] in ['Intermediate', 'Advanced'] and \
       project_types[i] in ['Data Analysis', 'Statistics']:
        language[i] = "SPSS"
    
    elif skill_level[i] in ['Intermediate', 'Advanced'] and \
       project_types[i] in ['Web Development', 'Backend Development', 'API Development']:
        language[i] = "Node.js"
        
    elif skill_level[i] in ['Intermediate', 'Advanced'] and \
       learning_style[i] in ['hands-on coding'] and \
       project_types[i] in ['Backend Development', 'Cloud Computing'] and \
       cross_platform_compatibility[i] == 'Yes' and \
       industry_trends[i] in ['Much', 'Rare'] and \
       documentation_importance[i] in ['Yes', 'Not sure']:
        language[i] = "Go"
        
    elif skill_level[i] in ['Intermediate', 'Advanced'] and \
       learning_style[i] in ['hands-on coding', 'visual programming'] and \
       project_types[i] in ['Mobile App Development', 'Web Development'] and \
       documentation_importance[i] in ['Yes', 'Not sure']:
        language[i] = "Kotlin"
        
    elif skill_level[i] in ['Intermediate', 'Advanced'] and \
       learning_style[i] in ['hands-on coding'] and \
       project_types[i] in ['Scripting', 'Automation']:
        language[i] = "Bash"

    elif skill_level[i] in ['Intermediate', 'Advanced'] and \
       project_types[i] in ['Web Development', 'Frontend Development', 'Full-stack Development'] and \
       industry_trends[i] in ['Much'] and \
       scalibility[i] in ['Small Scale', 'Large Scale', 'Mix of Both']:
        language[i] = "TypeScript"
    
    elif skill_level[i] in ['Beginner'] and \
       project_types[i] in ['API Development']:
        language[i] = "Node.js"
    
    elif skill_level[i] in ['Beginner'] and \
       project_types[i] in ['API Development'] and \
       ecosystems_and_tools[i] in ["Not Sure"]:
        language[i] = "Node.js"
    
        
    elif skill_level[i] in ['Beginner'] and \
       project_types[i] in ['API Development'] and \
       ecosystems_and_tools[i] in ["Yes"]:
        language[i] = "Python"
        
    elif skill_level[i] in ['Advanced'] and \
       project_types[i] in ['Argumented Reality and Virtual Reality']:
        language[i] = "C++"
    
    elif skill_level[i] in ['Beginner'] and \
       project_types[i] in ['Argumented Reality and Virtual Reality']:
        language[i] = "HTML, CSS, JavaScript"
    
    elif skill_level[i] in ['Intermediate'] and \
       project_types[i] in ['Argumented Reality and Virtual Reality']:
        language[i] = "C#"
    
    elif skill_level[i] in ['Beginner'] and \
       project_types[i] in ['Artificial Intelligence']:
        language[i] = "Python"
        
    elif skill_level[i] in ['Advanced'] and \
       project_types[i] in ['Artificial Intelligence']:
        language[i] = "R"
        
    elif skill_level[i] in ['Intermediate'] and \
       project_types[i] in ['Artificial Intelligence']:
        language[i] = "R"
        
    elif skill_level[i] in ['Beginner'] and \
       project_types[i] in ['Automation']:
        language[i] = "Python"
        
    elif skill_level[i] in ['Intermediate'] and \
       project_types[i] in ['Automation']:
        language[i] = "Java"
        
    elif skill_level[i] in ['Advanced'] and \
       project_types[i] in ['Automation']:
        language[i] = "Rust"
        
    elif skill_level[i] in ['Beginner'] and \
       project_types[i] in ['Blockchain Development']:
        language[i] = "JavaScript"
        
    elif skill_level[i] in ['Intermediate'] and \
       project_types[i] in ['Blockchain Development']:
        language[i] = "Go"
        
    elif skill_level[i] in ['Advanced'] and \
       project_types[i] in ['Blockchain Development'] and \
       cross_platform_compatibility[i] in ['Yes']:
        language[i] = "Java"
    
    elif skill_level[i] in ['Advanced'] and \
       project_types[i] in ['Blockchain Development'] and \
       cross_platform_compatibility[i] in ['Yes']:
        language[i] = "C++"
        
    elif skill_level[i] == 'Beginner' and \
       project_types[i] == 'Blockchain Development':
        language[i] = "JavaScript"  # Choose an appropriate language for beginners

    elif skill_level[i] == 'Intermediate' and \
       project_types[i] == 'Blockchain Development':
        if cross_platform_compatibility[i] == 'Yes':
            language[i] = "Go"  # Choose an appropriate language for intermediate level with cross-platform compatibility
        else:
            language[i] = "JavaScript"  # Choose another language for intermediate level without cross-platform compatibility

    elif skill_level[i] == 'Advanced' and \
       project_types[i] == 'Blockchain Development':
        if cross_platform_compatibility[i] == 'Yes':
            language[i] = "Java"  # Choose an appropriate language for advanced level with cross-platform compatibility
        else:
            language[i] = "C++"  # Choose another language for advanced level without cross-platform compatibility
            
    elif skill_level[i] == 'Beginner' and \
       project_types[i] == 'Cloud Computing':
        language[i] = "Python"  # Choose an appropriate language for beginners

    elif skill_level[i] == 'Intermediate' and \
       project_types[i] == 'Cloud Computing':
        if cross_platform_compatibility[i] == 'Yes':
            language[i] = "Go"  # Choose an appropriate language for intermediate level with cross-platform compatibility
        else:
            language[i] = "JavaScript"  # Choose another language for intermediate level without cross-platform compatibility

    elif skill_level[i] == 'Advanced' and \
       project_types[i] == 'Cloud Computing':
        if cross_platform_compatibility[i] == 'Yes':
            language[i] = "Java"  # Choose an appropriate language for advanced level with cross-platform compatibility
        else:
            language[i] = "C#"
            
    if skill_level[i] == 'Beginner' and \
       project_types[i] == 'Cybersecurity':
        language[i] = "Python"  # Choose an appropriate language for beginners

    elif skill_level[i] == 'Intermediate' and \
       project_types[i] == 'Cybersecurity':
        if data_handling[i] == 'Yes' and \
           documentation_importance[i] in ['Yes', 'Not sure']:
            language[i] = "Java"  # Choose an appropriate language for intermediate level with data handling and documentation importance
        else:
            language[i] = "C#"  # Choose another language for intermediate level

    elif skill_level[i] == 'Advanced' and \
       project_types[i] == 'Cybersecurity':
        if data_handling[i] == 'Yes' and \
           documentation_importance[i] in ['Yes', 'Not sure'] and \
           industry_trends[i] == 'Much':
            language[i] = "C++"  # Choose an appropriate language for advanced level with data handling, documentation importance, and high interest in industry trends
        else:
            language[i] = "Python"  # Choose another language for advanced level

    elif skill_level[i] == 'Beginner' and \
       project_types[i] == 'Data Analysis':
        language[i] = "Python"  # Choose an appropriate language for beginners

    elif skill_level[i] == 'Intermediate' and \
       project_types[i] == 'Data Analysis':
        if data_handling[i] == 'Yes' and \
           documentation_importance[i] in ['Yes', 'Not sure']:
            language[i] = "R"  # Choose an appropriate language for intermediate level with data handling and documentation importance
        else:
            language[i] = "Python"  # Choose another language for intermediate level

    elif skill_level[i] == 'Advanced' and \
       project_types[i] == 'Data Analysis':
        if data_handling[i] == 'Yes' and \
           documentation_importance[i] in ['Yes', 'Not sure'] and \
           industry_trends[i] == 'Much':
            language[i] = "R"
    
    elif skill_level[i] == 'Beginner' and \
       project_types[i] == 'Data Science':
        language[i] = "Python"  # Choose an appropriate language for beginners

    elif skill_level[i] == 'Intermediate' and \
       project_types[i] == 'Data Science':
        if data_handling[i] == 'Yes' and \
           industry_trends[i] in ['Much', 'Rare']:
            language[i] = "R"  # Choose an appropriate language for intermediate level with data handling and industry trend interest
        else:
            language[i] = "Python"  # Choose another language for intermediate level

    elif skill_level[i] == 'Advanced' and \
       project_types[i] == 'Data Science':
        if data_handling[i] == 'Yes' and \
           industry_trends[i] == 'Much' and \
           scalibility[i] in ['Small Scale', 'Large Scale', 'Mix of Both']:
            language[i] = "Python"  # Choose an appropriate language for advanced level with data handling, high industry trend interest, and scalability
        else:
            language[i] = "R"  # Choose another language for advanced level

    elif skill_level[i] == 'Beginner' and \
       project_types[i] == 'Desktop Application Development':
        language[i] = "C#"  # Choose an appropriate language for beginners

    elif skill_level[i] == 'Intermediate' and \
       project_types[i] == 'Desktop Application Development':
        if cross_platform_compatibility[i] == 'Yes' and \
           industry_trends[i] in ['Much', 'Rare']:
            language[i] = "Java"  # Choose an appropriate language for intermediate level with cross-platform compatibility and industry trend interest
        elif industry_trends[i] == 'Not at all':
            language[i] = "C++"  # Choose another language for intermediate level with no interest in industry trends
        else:
            language[i] = "C#"  # Choose another language for intermediate level

    elif skill_level[i] == 'Advanced' and \
       project_types[i] == 'Desktop Application Development':
        if cross_platform_compatibility[i] == 'Yes' and \
           industry_trends[i] == 'Much' and \
           scalibility[i] in ['Small Scale', 'Large Scale', 'Mix of Both']:
            language[i] = "Java"  # Choose an appropriate language for advanced level with cross-platform compatibility, high industry trend interest, and scalability
        elif industry_trends[i] == 'Not at all':
            language[i] = "C++"  # Choose another language for advanced level with no interest in industry trends
        else:
            language[i] = "C#"  # Choose another language for advanced level


    elif skill_level[i] == 'Beginner' and \
       project_types[i] == 'DevOps':
        language[i] = "Python"  # Choose an appropriate language for beginners

    elif skill_level[i] == 'Intermediate' and \
       project_types[i] == 'DevOps':
        if cross_platform_compatibility[i] == 'Yes' and \
           industry_trends[i] in ['Much', 'Rare']:
            language[i] = "Go"  # Choose an appropriate language for intermediate level with cross-platform compatibility and industry trend interest
        elif industry_trends[i] == 'Not at all':
            language[i] = "Python"  # Choose another language for intermediate level with no interest in industry trends
        else:
            language[i] = "Shell Scripting"  # Choose another language for intermediate level

    elif skill_level[i] == 'Advanced' and \
       project_types[i] == 'DevOps':
        if cross_platform_compatibility[i] == 'Yes' and \
           industry_trends[i] == 'Much' and \
           scalibility[i] in ['Small Scale', 'Large Scale', 'Mix of Both']:
            language[i] = "Go"  # Choose an appropriate language for advanced level with cross-platform compatibility, high industry trend interest, and scalability
        elif industry_trends[i] == 'Not at all':
            language[i] = "Python"  # Choose another language for advanced level with no interest in industry trends
        else:
            language[i] = "Java"  # Choose another language for advanced level


    elif skill_level[i] == 'Beginner' and \
       project_types[i] == 'E-commerce':
        language[i] = "PHP"  # Choose an appropriate language for beginners

    elif skill_level[i] == 'Intermediate' and \
       project_types[i] == 'E-commerce':
        if cross_platform_compatibility[i] == 'Yes' and \
           industry_trends[i] in ['Much', 'Rare']:
            language[i] = "Java"  # Choose an appropriate language for intermediate level with cross-platform compatibility and industry trend interest
        elif industry_trends[i] == 'Not at all':
            language[i] = "Python"  # Choose another language for intermediate level with no interest in industry trends
        else:
            language[i] = "JavaScript"  # Choose another language for intermediate level

    elif skill_level[i] == 'Advanced' and \
       project_types[i] == 'E-commerce':
        if cross_platform_compatibility[i] == 'Yes' and \
           industry_trends[i] == 'Much' and \
           scalibility[i] in ['Small Scale', 'Large Scale', 'Mix of Both']:
            language[i] = "Java"  # Choose an appropriate language for advanced level with cross-platform compatibility, high industry trend interest, and scalability
        elif industry_trends[i] == 'Not at all':
            language[i] = "C#"  # Choose another language for advanced level with no interest in industry trends
        else:
            language[i] = "Node.js"  # Choose another language for advanced level

    
    elif skill_level[i] == 'Beginner' and \
       project_types[i] == 'Embedded Systems':
        language[i] = "C"  # Choose an appropriate language for beginners

    elif skill_level[i] == 'Intermediate' and \
       project_types[i] == 'Embedded Systems':
        if cross_platform_compatibility[i] == 'Yes' and \
           industry_trends[i] in ['Much', 'Rare']:
            language[i] = "C++"  # Choose an appropriate language for intermediate level with cross-platform compatibility and industry trend interest
        elif industry_trends[i] == 'Not at all':
            language[i] = "Assembly"  # Choose another language for intermediate level with no interest in industry trends
        else:
            language[i] = "Python"  # Choose another language for intermediate level

    elif skill_level[i] == 'Advanced' and \
       project_types[i] == 'Embedded Systems':
        if cross_platform_compatibility[i] == 'Yes' and \
           industry_trends[i] == 'Much' and \
           scalibility[i] in ['Small Scale', 'Large Scale', 'Mix of Both']:
            language[i] = "C++"  # Choose an appropriate language for advanced level with cross-platform compatibility, high industry trend interest, and scalability
        elif industry_trends[i] == 'Not at all':
            language[i] = "Assembly"  # Choose another language for advanced level with no interest in industry trends
        else:
            language[i] = "C"  
            
    elif skill_level[i] == 'Beginner' and \
       project_types[i] in ['Frontend Development']:
        language[i] = "HTML, CSS, JavaScript"  # Choose an appropriate language for beginners

    elif skill_level[i] in ['Intermediate', 'Advanced'] and \
       project_types[i] in ['Frontend Development']:
        if documentation_importance[i] in ['Yes', 'Not sure']:
            language[i] = "React"  # Choose an appropriate language for intermediate and advanced levels with documentation importance
        else:
            language[i] = "Vue.js"  # Choose another language for intermediate and advanced levels without documentation importance

    # Additional conditions for including more languages
    elif skill_level[i] in ['Intermediate', 'Advanced'] and \
       project_types[i] in ['Full-stack Development']:
        if cross_platform_compatibility[i] == 'Yes':
            language[i] = "TypeScript"  # Choose TypeScript for full-stack development with cross-platform compatibility
        else:
            language[i] = "JavaScript"  # Choose JavaScript for full-stack development without cross-platform compatibility

    elif skill_level[i] in ['Intermediate', 'Advanced'] and \
       project_types[i] in ['Web Development', 'E-commerce']:
        if cross_platform_compatibility[i] == 'Yes' and \
           industry_trends[i] in ['Much', 'Rare']:
            language[i] = "Angular"  # Choose an appropriate language for web development with cross-platform compatibility and high industry trend interest
        else:
            language[i] = "JavaScript"  # Choose another language for web development

            
    elif skill_level[i] == 'Beginner' and \
       project_types[i] in ['Full-stack Development']:
        language[i] = "HTML, CSS, JavaScript"  # Choose an appropriate language for beginners

    elif skill_level[i] in ['Intermediate', 'Advanced'] and \
       project_types[i] in ['Full-stack Development']:
        if cross_platform_compatibility[i] == 'Yes' and \
           industry_trends[i] in ['Much', 'Rare']:
            language[i] = "MERN Stack"  # Choose an appropriate language for intermediate and advanced levels with cross-platform compatibility and high industry trend interest
        else:
            language[i] = "MEAN Stack"  # Choose another language for intermediate and advanced levels without cross-platform compatibility or low industry trend interest

    # Additional conditions for including more languages
    elif skill_level[i] in ['Intermediate', 'Advanced'] and \
       project_types[i] in ['Web Development', 'E-commerce']:
        if cross_platform_compatibility[i] == 'Yes' and \
           industry_trends[i] == 'Much':
            language[i] = "Django"  # Choose an appropriate language for web development with cross-platform compatibility and high industry trend interest
        else:
            language[i] = "Ruby on Rails"  # Choose another language for web development

    
    elif skill_level[i] == 'Beginner' and \
       project_types[i] == 'Game Development':
        language[i] = "Scratch"  # Choose an appropriate language for beginners

    elif skill_level[i] in ['Intermediate', 'Advanced'] and \
       project_types[i] == 'Game Development':
        if cross_platform_compatibility[i] == 'Yes' and \
           industry_trends[i] in ['Much', 'Rare']:
            language[i] = "Unity (C#)"  # Choose an appropriate language for intermediate and advanced levels with cross-platform compatibility and high industry trend interest
        else:
            language[i] = "Godot (GDScript)"  # Choose another language for intermediate and advanced levels without cross-platform compatibility or low industry trend interest

            
    elif skill_level[i] == 'Beginner' and \
       project_types[i] == 'Healthcare IT':
        language[i] = "Python"  # Choose an appropriate language for beginners

    elif skill_level[i] in ['Intermediate', 'Advanced'] and \
       project_types[i] == 'Healthcare IT':
        if cross_platform_compatibility[i] == 'Yes' and \
           industry_trends[i] in ['Much', 'Rare']:
            language[i] = "Java"  # Choose an appropriate language for intermediate and advanced levels with cross-platform compatibility and high industry trend interest
        else:
            language[i] = "C#" 
            
    elif skill_level[i] == 'Beginner' and \
       project_types[i] == 'Internet of Things':
        language[i] = "Arduino (C++)"  # Choose an appropriate language for beginners

    elif skill_level[i] in ['Intermediate', 'Advanced'] and \
       project_types[i] == 'Internet of Things':
        if cross_platform_compatibility[i] == 'Yes' and \
           industry_trends[i] in ['Much', 'Rare']:
            language[i] = "Python"  # Choose an appropriate language for intermediate and advanced levels with cross-platform compatibility and high industry trend interest
        else:
            language[i] = "C++" 
            
    if skill_level[i] == 'Beginner' and \
       project_types[i] in ['Mobile App Development']:
        language[i] = "Swift"  # Choose an appropriate language for beginners in iOS development

    elif skill_level[i] == 'Beginner' and \
       project_types[i] in ['Android App Development']:
        language[i] = "Kotlin"  # Choose an appropriate language for beginners in Android development

    elif skill_level[i] in ['Intermediate', 'Advanced'] and \
       project_types[i] in ['Mobile App Development']:
        if cross_platform_compatibility[i] == 'Yes' and \
           industry_trends[i] in ['Much', 'Rare']:
            language[i] = "React Native (JavaScript)"  # Choose React Native for cross-platform development with high industry trend interest
        else:
            language[i] = "Swift (iOS)"  # Choose Swift for iOS development without cross-platform compatibility

    elif skill_level[i] in ['Intermediate', 'Advanced'] and \
       project_types[i] in ['Android App Development']:
        if cross_platform_compatibility[i] == 'Yes' and \
           industry_trends[i] in ['Much', 'Rare']:
            language[i] = "Flutter (Dart)"  # Choose Flutter for cross-platform development with high industry trend interest
        else:
            language[i] = "Kotlin (Android)" 
            
    elif skill_level[i] == 'Beginner' and \
       project_types[i] in ['Scripting']:
        language[i] = "Python"  # Choose an appropriate language for beginners in scripting

    elif skill_level[i] in ['Intermediate', 'Advanced'] and \
       project_types[i] in ['Scripting']:
        if cross_platform_compatibility[i] == 'Yes' and \
           industry_trends[i] in ['Much', 'Rare']:
            language[i] = "PowerShell"  # Choose PowerShell for scripting with high industry trend interest and cross-platform compatibility
        else:
            language[i] = "Bash"  # Choose Bash for scripting without cross-platform compatibility or low industry trend interest

    
    
    elif skill_level[i] == 'Beginner' and \
       project_types[i] in ['Signal Processing']:
        language[i] = "MATLAB"  # Choose MATLAB for beginners in signal processing

    elif skill_level[i] in ['Intermediate', 'Advanced'] and \
       project_types[i] in ['Signal Processing']:
        if cross_platform_compatibility[i] == 'Yes' and \
           industry_trends[i] in ['Much', 'Rare']:
            language[i] = "Python (NumPy, SciPy)"  # Choose Python with NumPy and SciPy for signal processing with high industry trend interest and cross-platform compatibility
        else:
            language[i] = "C++ (OpenCV)"
            
    elif skill_level[i] == 'Beginner' and \
       project_types[i] in ['Statistics']:
        language[i] = "R"  # Choose R for beginners in statistics

    elif skill_level[i] in ['Intermediate', 'Advanced'] and \
       project_types[i] in ['Statistics']:
        if cross_platform_compatibility[i] == 'Yes' and \
           industry_trends[i] in ['Much', 'Rare']:
            language[i] = "Python (NumPy, pandas, SciPy)"  # Choose Python with NumPy, pandas, and SciPy for statistics with high industry trend interest and cross-platform compatibility
        else:
            language[i] = "SPSS" 
    
    elif skill_level[i] == 'Beginner' and \
       project_types[i] in ['System Administration']:
        language[i] = "Bash"  # Choose Bash for beginners in system administration

    elif skill_level[i] in ['Intermediate', 'Advanced'] and \
       project_types[i] in ['System Administration']:
        if cross_platform_compatibility[i] == 'Yes' and \
           industry_trends[i] in ['Much', 'Rare']:
            language[i] = "PowerShell"  # Choose PowerShell for system administration with high industry trend interest and cross-platform compatibility
        else:
            language[i] = "Python"
            
    
    elif skill_level[i] == 'Beginner' and \
       project_types[i] in ['System Programming']:
        language[i] = "C"  # Choose C for beginners in system programming

    elif skill_level[i] in ['Intermediate', 'Advanced'] and \
       project_types[i] in ['System Programming']:
        if cross_platform_compatibility[i] == 'Yes' and \
           industry_trends[i] in ['Much', 'Rare']:
            language[i] = "C++"  # Choose C++ for system programming with high industry trend interest and cross-platform compatibility
        else:
            language[i] = "Assembly" 
            
    if skill_level[i] == 'Beginner' and \
       project_types[i] in ['Web Development']:
        language[i] = "HTML, CSS, JavaScript"  # Choose HTML, CSS, and JavaScript for beginners in web development

    elif skill_level[i] in ['Intermediate', 'Advanced'] and \
       project_types[i] in ['Web Development']:
        if cross_platform_compatibility[i] == 'Yes' and \
           industry_trends[i] in ['Much', 'Rare']:
            language[i] = "React.js (JavaScript)"  # Choose React.js with JavaScript for web development with high industry trend interest and cross-platform compatibility
        else:
            language[i] = "Angular.js (JavaScript)"

# %%
df = pd.DataFrame({
    'Skill': skill_level,
    'LearningStyle': learning_style,
    'ProjectType': project_types,
    'PlatformCompatibility': cross_platform_compatibility,
    'IndustrtTrends': industry_trends,
    'Ecosystems': ecosystems_and_tools,
    'Scalibility':scalibility,
    'DataHandling':data_handling,
    'Documentation':documentation_importance,
    'Language':language
})

# Display the first few rows of the dataset
print(df.head(1000))
# Out:
#             Skill         LearningStyle             ProjectType  \
# 0        Beginner       hands-on coding      System Programming
# 1        Beginner       hands-on coding              Statistics
# 2        Beginner       hands-on coding        Game Development
# 3    Intermediate    visual programming      System Programming
# 4    Intermediate    visual programming       Signal Processing
# ..            ...                   ...                     ...
# 995  Intermediate       hands-on coding         Cloud Computing
# 996      Beginner  Theoritical approach         Web Development
# 997  Intermediate  Theoritical approach        Game Development
# 998      Advanced       hands-on coding  Full-stack Development
# 999      Beginner  Theoritical approach  Mobile App Development
#
#     PlatformCompatibility IndustrtTrends Ecosystems  Scalibility DataHandling  \
# 0                      No           Much        Yes  Small Scale     Not sure
# ...

# %%
df.to_excel('datasets/languageFinal.xlsx', index=False)
